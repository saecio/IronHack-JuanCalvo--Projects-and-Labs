# %% [markdown]
# # Lab | Data Structures

# %% [markdown]
# ## Exercise: Managing Customer Orders
#
# As part of a business venture, you are starting an online store that sells various products. To ensure smooth operations, you need to develop a program that manages customer orders and inventory.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
#
# 2. Create an empty dictionary called `inventory`.
#
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.
#
# 4. Create an empty set called `customer_orders`.
#
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.
#
# 6. Print the products in the `customer_orders` set.
#
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.
#
# 8. Print the order statistics using the following format:
#    ```
#    Order Statistics:
#    Total Products Ordered: <total_products_ordered>
#    Percentage of Products Ordered: <percentage_ordered>%
#    ```
#
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.
#
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.
#
# Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.

# %% [markdown]
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".

# %%
products = ["t-shirt", "mug", "hat", "book", "keychain"]

# %% [markdown]
# 2. Create an empty dictionary called `inventory`.

# %%
inventory = {}

# %%
print(type(inventory))
# Out:
# <class 'dict'>

# %% [markdown]
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.

# %%
inventory["t-shirt"] = int(input("Please add the amount of t-shirts: "))
inventory["mug"] = int(input("Please add the amount of mugs: "))
inventory["hat"] = int(input("Please add the amount of hats: "))
inventory["book"] = int(input("Please add the amount of books: "))
inventory["keychain"] = int(input("Please add the amount of keychains: "))
# Out:
# Please add the amount of t-shirts:  5
# Please add the amount of mugs:  4
# Please add the amount of hats:  3
# Please add the amount of books:  6
# Please add the amount of keychains:  1

# %% [markdown]
# 4. Create an empty set called `customer_orders`.

# %% [markdown]
# 4. Create an empty set called `customer_orders`.

# %%
inventory
# Out:
# {'t-shirt': 5, 'mug': 4, 'hat': 3, 'book': 6, 'keychain': 1}

# %%
customer_orders = set()

# %%
type(customer_orders)
# Out:
# set

# %% [markdown]
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.

# %%
print("Please add three products you want to order: 't-shirt', 'mug', 'hat', 'book' or 'keychain'")

customer_orders.add(input("Please add one product: "))
customer_orders.add(input("Please add another product: "))
customer_orders.add(input("Please add last product: "))
# Out:
# Please add three products you want to order: 't-shirt', 'mug', 'hat', 'book' or 'keychain'
# Please add one product:  t-shirt
# Please add another product:  mug
# Please add last product:  hat

# %% [markdown]
# 6. Print the products in the `customer_orders` set.

# %%
print(customer_orders)
# Out:
# {'t-shirt', 'mug', 'hat'}

# %% [markdown]
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.

# %%
#Total products ordered
products_ordered = len(customer_orders)

# %%
inventory
# Out:
# {'t-shirt': 5, 'mug': 4, 'hat': 3, 'book': 6, 'keychain': 1}

# %%
sum(inventory.values())
# Out:
# 19

# %%
percentage_products_ordered = ((len(customer_orders))/sum(inventory.values()))*100

# %%
percentage_products_ordered
# Out:
# 15.789473684210526

# %%
order_status = (products_ordered , percentage_products_ordered)

# %%
order_status
# Out:
# (3, 15.789473684210526)

# %% [markdown]
# 8. Print the order statistics using the following format:
#    ```
#    Order Statistics:
#    Total Products Ordered: <total_products_ordered>
#    Percentage of Products Ordered: <percentage_ordered>%
#    ```

# %%
print("Order statistics:")
print(f"Total Products Ordered: {products_ordered}")
print(f"Percentage of Products Ordered: {percentage_products_ordered}%")
# Out:
# Order statistics:
# Total Products Ordered: 3
# Percentage of Products Ordered: 15.789473684210526%

# %% [markdown]
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.

# %%
inventory
# Out:
# {'t-shirt': 5, 'mug': 4, 'hat': 3, 'book': 6, 'keychain': 1}

# %%
inventory["t-shirt"] = 4
inventory["mug"] = 3
inventory["hat"] = 2

# %%
inventory
# Out:
# {'t-shirt': 4, 'mug': 3, 'hat': 2, 'book': 6, 'keychain': 1}

# %% [markdown]
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.

# %%
print("This is the updated inventory:")
print("t-shirt: ", inventory.get("t-shirt"))
print("mug: ", inventory.get("mug"))
print("hat: ", inventory.get("hat"))
print("book: ", inventory.get("book"))
print("keychain: ", inventory.get("keychain"))
# Out:
# This is the updated inventory:
# t-shirt:  4
# mug:  3
# hat:  2
# book:  6
# keychain:  1
